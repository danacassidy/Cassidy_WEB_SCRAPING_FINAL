# %%
# Scraping Deathrow Inmates - Florida Department of Corrections

# %%
from urllib.request import urlopen
import bs4
from bs4 import BeautifulSoup
import re
import time
import csv
import requests

# %%
my_url = 'http://www.dc.state.fl.us/OffenderSearch/deathrowroster.aspx'
def scrape_links(my_url):
    res = requests.get(my_url)
    soup= bs4.BeautifulSoup(res.text,"html.parser")

        # collect every row in our soup
    inmate_rows = soup.find_all("tr")

        # make a blank list that we will append our information to
    inmate_links = []

        # for every row in our list inmate_rows, we are going to take all of the table data we need in a try and except. 
        #This try and except exists because some rows don't have the proper data we are looking for and will throw errors unless we stop them ahead of time.
    for row in inmate_rows:

        try:
                   # getting our table data
                a_inmate = row.find("a")
                href_inmate = a_inmate.get("href")
                    #let's make a dictionary. We can assign keys and attributes to ensure that we're inputting the right info into our CSV
                    # we're also going to strip our text because it's really ugly if we don't.
                inmate_links.append(href_inmate)
        except:
                continue

    return inmate_links

# %%
scrape_links(my_url)
# Out:
# ['/offenderSearch/detail.aspx?Page=Detail&DCNumber=011225&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=008035&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=053948&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=056338&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=058279&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=058293&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=053779&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=044049&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=068610&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=071615&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=073045&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=072847&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=075812&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=322534&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=078081&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=083040&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=084582&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=084643&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=085488&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=086006&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=087429&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=789049&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=088568&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=090411&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=749768&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=490606&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=093094&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=093268&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=093417&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=716927&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=094506&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=072002&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=648711&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=910610&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=099269&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=101660&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=648254&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=073283&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=102992&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=479774&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=105661&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=092501&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=106014&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=019762&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=640779&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=573461&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=108509&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=040002&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=226426&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=639131&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=072746&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=042115&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=046651&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=019513&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=111508&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=111918&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=112232&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=097494&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=112850&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=112967&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=115769&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=086160&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=116320&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=117157&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=286020&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=096867&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=119682&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=119773&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=394141&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=188854&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=120467&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=751166&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=256512&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=729185&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=616550&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=065145&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=324342&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=039763&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=812974&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=121965&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=122079&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=182543&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=351997&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=699349&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=122551&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=100063&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=338043&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=649748&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=138315&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=288322&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=288500&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=707742&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=335421&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=217358&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=721842&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=071551&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=220267&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=440701&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=936283&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=062368&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=368527&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=516349&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=490989&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=321031&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=122995&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=110365&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=120190&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=726848&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=713735&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=420481&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=123069&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=123096&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=115624&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=268130&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=941687&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=318987&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=118167&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=116335&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=905288&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=330290&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=309066&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=214353&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=447891&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=048606&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=311509&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=310094&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=445903&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=445904&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=123763&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=962032&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=665786&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=061360&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=123846&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=123847&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=379799&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=026985&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=300807&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=450307&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=969121&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=990054&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=764970&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=123911&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=180399&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=610979&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=124052&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=108426&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=709795&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=554000&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=124283&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=P01395&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=286173&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=721097&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=989102&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=395352&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=124346&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=122651&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=375690&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=391485&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=X06883&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=124400&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=124439&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=124460&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=071588&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=124493&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=356054&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=066600&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=Y01561&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J08118&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=M16320&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=M16321&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=668630&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=W08567&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=H06832&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=124607&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=X18736&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=550026&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=763722&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=572349&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=911193&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=124639&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=059121&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J12116&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=Y02046&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=567668&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=N00676&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=664697&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=535168&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=V02093&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=347463&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=898522&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=314648&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=096344&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=123101&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=282008&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=218693&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=166224&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=124849&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=M25274&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=105559&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=927442&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=R05023&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=166626&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=125172&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=H10118&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=699893&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=Q13157&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=R30302&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=K04389&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=105669&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=291140&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=B01314&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=324170&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=645118&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=K51342&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=326252&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=111640&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=X33939&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=192202&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=L49959&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=H12548&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=H23012&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J29642&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=127513&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J30192&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=128135&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=V26165&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=898405&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=991988&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=L36345&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=129232&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=167421&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J34141&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=406356&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=588873&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=349878&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J35401&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J35212&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=U33164&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=130335&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J29603&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J03479&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=165328&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=130930&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=185563&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J01369&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=512579&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=124356&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=V25581&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=378912&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=V14470&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=358986&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=131596&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=197598&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=200047&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=X45131&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=132254&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=287224&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=Q23494&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J30258&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J40507&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=133220&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=M03128&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J20499&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=768915&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=133897&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=H27248&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=699575&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=444904&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=130985&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=120774&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=L88290&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=D30662&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J25731&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=U44139&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J46231&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J18546&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=Q26629&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=436687&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=155917&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=801152&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=N08206&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=H17413&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=135556&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=135769&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=R17884&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=180632&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=135963&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=135997&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=X46345&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=U21898&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=U41472&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=D51268&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=U13479&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=148538&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=T36280&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=V24323&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=L97205&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=R56925&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=182201&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=C00181&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J53288&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=132862&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=W34427&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=140726&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=Y63399&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=D24647&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=T72309&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=986205&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=K05966&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=Y80029&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=M61417&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J29399&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=J80689&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=H07698&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=T85161&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=W49706&TypeSearch=AI',
#  '/offenderSearch/detail.aspx?Page=Detail&DCNumber=D46851&TypeSearch=AI']

# %%
filename = 'inmateinfo_dana_webscrapingproject_output.csv' 

column_headings = ['DC Number', 'Name', 'Race', "Sex", "Birth Date", "Inititial Receipt Date", "Current Facility",
                      "Current Custody", "Current Release Date", "Custody Status","Visiting Request Form - Part 1", 
                   "Visiting Request Form - Part 2", "How to Apply for Visitation", "Detainer Information"]

csvfile = open(filename, 'w', newline='', encoding='utf-8')

c = csv.writer(csvfile)
c.writerow(column_headings)
# Out:
# 239

# %%
def scrape_info(my_url):
    inmate = []
    combo_url = ("http://www.dc.state.fl.us/" + str(my_url))
    page =requests.get(combo_url)
    soup = BeautifulSoup(page.text, 'html.parser')
    table = soup.find("table", class_="offenderDetails")
    data = table.find_all("td")
    
    for cell in data:
        if cell.find("a") in cell:
            a_tag = cell.find("a")
            href_link = a_tag.get('href')
            inmate.append(href_link)
            
        elif cell.find("a") not in cell:    
            cleaned_inmate = cell.get_text().strip()
            inmate.append(cleaned_inmate)
        else:
            inmate.append("n/a")
    
    c.writerow(inmate)

# %%
for link in inmate_links:
    scrape_info(link)

# %%
offense_column_headings = ["DC Number","Offense Date", "Offense", "Sentence Date", "County",
                      "Case No.", "Prison Sentence Length"]


filename = 'offenseinfo_dana_webscrapingproject_output.csv' 


csvfile = open(filename, 'w', newline='', encoding='utf-8')

c = csv.writer(csvfile)
c.writerow(offense_column_headings)
# Out:
# 85

# %%
def offense_scrape(my_url):
    combo_url = ("http://www.dc.state.fl.us/" + str(my_url))
    page =requests.get(combo_url)
    soup = BeautifulSoup(page.text, 'html.parser')
    big_table = soup.find("table", class_ = "dcCSStableAlias")
    table = big_table.find_all("tr")
    
    for row in table:
        offense_row = []
        if row.find("td") in row:
            data = row.find_all("td")
            DC_number= soup.find("td")
            offense_row.append(DC_number.text)
            
            for d in data:
                cleaned_offense_row = d.get_text().strip()
                offense_row.append(cleaned_offense_row)
            c.writerow(offense_row)
            
        else:
            continue

# %%
for link in inmate_links:
    offense_scrape(link)
